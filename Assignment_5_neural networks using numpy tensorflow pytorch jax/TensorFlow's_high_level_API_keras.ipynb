# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
import numpy as np

class FunctionalModel:
    def __init__(self, input_shape):
        self.model = self.build_model(input_shape)

    def build_model(self, input_shape):
        inputs = Input(shape=input_shape)
        x = Dense(64, activation='relu')(inputs)
        x = Dense(64, activation='relu')(x)
        outputs = Dense(1)(x)
        model = Model(inputs=inputs, outputs=outputs)
        return model

    def compile(self):
        self.model.compile(optimizer='adam', loss='mse')

    def fit(self, X_train, y_train, epochs=100, batch_size=32, validation_split=0.2):
        self.model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=validation_split)

    def evaluate(self, X_test, y_test):
        test_loss = self.model.evaluate(X_test, y_test)
        print(f"Test Loss: {test_loss}")

# Assume generate_data() is defined as shown previously
def generate_data(num_samples=1000):
    np.random.seed(42)
    x = np.random.uniform(-2, 2, num_samples)
    y = np.random.uniform(-2, 2, num_samples)
    z = np.random.uniform(-2, 2, num_samples)
    f_xyz = np.sin(x) + np.cos(y) * np.power(z, 2)
    features = np.vstack((x, y, z)).T
    outputs = f_xyz
    return features, outputs

# Generate synthetic data
features, outputs = generate_data()

# Prepare the data
X_train, X_test, y_train, y_test = train_test_split(features, outputs, test_size=0.2, random_state=42)

# Create and use the model
model_wrapper = FunctionalModel(input_shape=(3,))
model_wrapper.compile()
model_wrapper.fit(X_train, y_train)
model_wrapper.evaluate(X_test, y_test)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 2s 20ms/step - loss: 1.4718 - val_loss: 0.9461
# Epoch 2/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8478 - val_loss: 0.6125
# Epoch 3/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6166 - val_loss: 0.4290
# Epoch 4/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4580 - val_loss: 0.3296
# Epoch 5/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.3457 - val_loss: 0.2484
# Epoch 6/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.2832 - val_loss: 0.2083
# Epoch 7/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.2469 - val_loss: 0.1835
# Epoch 8/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.2179 - val_loss: 0.1728
# Epoch 9/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1938 - val_loss: 0.1425
# Epoch 10/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1729 - val_loss: 0.1359
# Epoch 11/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1559 - val_loss: 0.1296
# Epoch 12/100
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1372 - val_loss: 0.1376
# Epoch 13/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1292 - val_loss: 0.1105
# Epoch 14/100
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1208 - val_loss: 0.1167
# Epoch 15/100
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1191 - val_loss: 0.1083
# Epoch 16/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1123 - val_loss: 0.0985
# Epoch 17/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1033 - val_loss: 0.0952
# Epoch 18/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0985 - val_loss: 0.0990
# Epoch 19/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0951 - val_loss: 0.0893
# Epoch 20/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0917 - val_loss: 0.0860
# Epoch 21/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0866 - val_loss: 0.0952
# Epoch 22/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0862 - val_loss: 0.0840
# Epoch 23/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0864 - val_loss: 0.0896
# Epoch 24/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0879 - val_loss: 0.0839
# Epoch 25/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0831 - val_loss: 0.0906
# Epoch 26/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0814 - val_loss: 0.0811
# Epoch 27/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0783 - val_loss: 0.0899
# Epoch 28/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0779 - val_loss: 0.0798
# Epoch 29/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0744 - val_loss: 0.0744
# Epoch 30/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0737 - val_loss: 0.0787
# Epoch 31/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0719 - val_loss: 0.0706
# Epoch 32/100
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0729 - val_loss: 0.0691
# Epoch 33/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0737 - val_loss: 0.0705
# Epoch 34/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0679 - val_loss: 0.0666
# Epoch 35/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0655 - val_loss: 0.0691
# Epoch 36/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0661 - val_loss: 0.0658
# Epoch 37/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0661 - val_loss: 0.0657
# Epoch 38/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0639 - val_loss: 0.0654
# Epoch 39/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0607 - val_loss: 0.0655
# Epoch 40/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0577 - val_loss: 0.0565
# Epoch 41/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0559 - val_loss: 0.0566
# Epoch 42/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0555 - val_loss: 0.0680
# Epoch 43/100
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0560 - val_loss: 0.0566
# Epoch 44/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0521 - val_loss: 0.0540
# Epoch 45/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0515 - val_loss: 0.0491
# Epoch 46/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0500 - val_loss: 0.0495
# Epoch 47/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0506 - val_loss: 0.0479
# Epoch 48/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0482 - val_loss: 0.0492
# Epoch 49/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0459 - val_loss: 0.0530
# Epoch 50/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0434 - val_loss: 0.0436
# Epoch 51/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0420 - val_loss: 0.0447
# Epoch 52/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0425 - val_loss: 0.0417
# Epoch 53/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0430 - val_loss: 0.0456
# Epoch 54/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0412 - val_loss: 0.0488
# Epoch 55/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0403 - val_loss: 0.0438
# Epoch 56/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0369 - val_loss: 0.0373
# Epoch 57/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0372 - val_loss: 0.0417
# Epoch 58/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0366 - val_loss: 0.0384
# Epoch 59/100
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0345 - val_loss: 0.0364
# Epoch 60/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0330 - val_loss: 0.0363
# Epoch 61/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0333 - val_loss: 0.0385
# Epoch 62/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0340 - val_loss: 0.0352
# Epoch 63/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0319 - val_loss: 0.0369
# Epoch 64/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0318 - val_loss: 0.0350
# Epoch 65/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0292 - val_loss: 0.0333
# Epoch 66/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0285 - val_loss: 0.0358
# Epoch 67/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0296 - val_loss: 0.0327
# Epoch 68/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0268 - val_loss: 0.0317
# Epoch 69/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0271 - val_loss: 0.0327
# Epoch 70/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0258 - val_loss: 0.0335
# Epoch 71/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0268 - val_loss: 0.0344
# Epoch 72/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0255 - val_loss: 0.0333
# Epoch 73/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0252 - val_loss: 0.0329
# Epoch 74/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0247 - val_loss: 0.0304
# Epoch 75/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0239 - val_loss: 0.0281
# Epoch 76/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0242 - val_loss: 0.0293
# Epoch 77/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0253 - val_loss: 0.0287
# Epoch 78/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0242 - val_loss: 0.0305
# Epoch 79/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0210 - val_loss: 0.0273
# Epoch 80/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0201 - val_loss: 0.0287
# Epoch 81/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0203 - val_loss: 0.0276
# Epoch 82/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0196 - val_loss: 0.0268
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0212 - val_loss: 0.0279
# Epoch 84/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0202 - val_loss: 0.0267
# Epoch 85/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0187 - val_loss: 0.0238
# Epoch 86/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0198 - val_loss: 0.0296
# Epoch 87/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0209 - val_loss: 0.0283
# Epoch 88/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0200 - val_loss: 0.0257
# Epoch 89/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0175 - val_loss: 0.0225
# Epoch 90/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0171 - val_loss: 0.0214
# Epoch 91/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0170 - val_loss: 0.0229
# Epoch 92/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0172 - val_loss: 0.0238
# Epoch 93/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0161 - val_loss: 0.0209
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0150 - val_loss: 0.0211
# Epoch 95/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0152 - val_loss: 0.0212
# Epoch 96/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0150 - val_loss: 0.0202
# Epoch 97/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0148 - val_loss: 0.0211
# Epoch 98/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0156 - val_loss: 0.0221
# Epoch 99/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0146 - val_loss: 0.0203
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0134 - val_loss: 0.0192
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0253
# Test Loss: 0.025250867009162903
