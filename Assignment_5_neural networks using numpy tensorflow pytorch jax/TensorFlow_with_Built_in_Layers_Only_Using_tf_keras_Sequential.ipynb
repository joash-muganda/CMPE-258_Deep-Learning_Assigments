# %% [markdown]
# # **TensorFlow with Built-in Layers Only Using tf.keras.Sequential**

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

def generate_data(num_samples=1000):
    np.random.seed(42)  # For reproducible results
    x = np.random.uniform(-2, 2, num_samples)
    y = np.random.uniform(-2, 2, num_samples)
    z = np.random.uniform(-2, 2, num_samples)
    f_xyz = np.sin(x) + np.cos(y) * np.power(z, 2)  # Non-linear equation
    features = np.vstack((x, y, z)).T
    outputs = f_xyz
    return features, outputs

features, outputs = generate_data()  # Generates synthetic dataset

# Assuming you've already defined `generate_data`
input_size = features.shape[1]  # This will be 3 as per generate_data function

def build_model(input_shape):
    model = Sequential([
        Dense(64, activation='relu', input_shape=(input_shape,)),  # Initialize the first layer with input shape
        Dense(64, activation='relu'),  # Second hidden layer
        Dense(1)  # Output layer
    ])
    return model

# Compile the model
model = build_model(input_size)
model.compile(optimizer='adam', loss='mse')

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, outputs, test_size=0.2, random_state=42)

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
# Out:
# Epoch 1/100
# 20/20 [==============================] - 3s 24ms/step - loss: 1.6731 - val_loss: 1.0547
# Epoch 2/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9263 - val_loss: 0.6409
# Epoch 3/100
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6550 - val_loss: 0.4860
# Epoch 4/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5052 - val_loss: 0.3556
# Epoch 5/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3842 - val_loss: 0.2631
# Epoch 6/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3097 - val_loss: 0.2404
# Epoch 7/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2663 - val_loss: 0.2014
# Epoch 8/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2285 - val_loss: 0.1783
# Epoch 9/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2037 - val_loss: 0.1530
# Epoch 10/100
# ...
